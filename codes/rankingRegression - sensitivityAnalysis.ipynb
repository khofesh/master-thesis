# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.externals import joblib
# sensitivity analysis
from SALib.sample import saltelli
from SALib.analyze import sobol
from SALib.test_functions import Ishigami

# %%
# load saved model
model = joblib.load('./training/regressor_mlp_new.pkl')

# %%
# merchanttype2, merchanttype3, topads, cashback, 
# cashbackval, price, prodrating, reviewcount, 
# negreview, posreview, answercnt, otheragreemean, 
# ratingmosthelpful, possentiment, negsentiment, sentipolarity, 
# reviewersrep, revpictotal, prodpicstotal
problem = {
  'num_vars': 19,
  'names': ['merchanttype2', 'merchanttype3', 'topads', 'cashback', 'cashbackval', 'price', 'prodrating', 
            'reviewcount', 'negreview', 'posreview', 'answercnt', 'otheragreemean', 'ratingmosthelpful', 
            'possentiment', 'negsentiment', 'sentipolarity', 'reviewersrep', 'revpictotal', 'prodpicstotal'],
  'bounds': [[0,1]]*19
}

# Generate samples
param_values = saltelli.sample(problem, 1000)

# %%
param_values.shape
# Out:
# (40000, 19)

# %%
# run model
Y = np.zeros([param_values.shape[0]])
for i, X in enumerate(param_values):
    # neural network model
    Y[i] = model.predict(X.reshape((1,-1)))

# %%
# Perform analysis
Si = sobol.analyze(problem, Y, print_to_console=True)
# Returns a dictionary with keys 'S1', 'S1_conf', 'ST', and 'ST_conf'
# (first and total-order indices with bootstrap confidence intervals)
# Out:
# Parameter S1 S1_conf ST ST_conf
# merchanttype2 0.001389 0.003370 0.001511 0.000228
# merchanttype3 -0.000790 0.001854 0.000482 0.000074
# topads 0.000556 0.002664 0.000800 0.000130
# cashback 0.000984 0.001081 0.000148 0.000027
# cashbackval 0.016475 0.012971 0.018837 0.006440
# price 0.320142 0.063778 0.446302 0.051356
# prodrating 0.000754 0.003645 0.001888 0.000410
# reviewcount 0.407346 0.050002 0.566409 0.068163
# negreview -0.000274 0.002872 0.001212 0.000159
# posreview -0.000156 0.004772 0.003107 0.000480
# answercnt 0.087731 0.024397 0.113598 0.016451
# otheragreemean -0.000928 0.001424 0.000211 0.000045
# ratingmosthelpful 0.000943 0.002759 0.000987 0.000133
# possentiment 0.000368 0.002092 0.000846 0.000159
# negsentiment 0.000315 0.003445 0.001451 0.000265
# sentipolarity 0.000765 0.004325 0.002208 0.000320
# reviewersrep 0.000000 0.000000 0.000000 0.000000
# revpictotal 0.021454 0.016345 0.035103 0.004866
# prodpicstotal -0.000357 0.005543 0.003819 0.000539
#
# Parameter_1 Parameter_2 S2 S2_conf
# merchanttype2 merchanttype3 0.001402 0.004710
# merchanttype2 topads 0.001425 0.004741
# merchanttype2 cashback 0.001388 0.004708
# merchanttype2 cashbackval 0.001404 0.004804
# merchanttype2 price 0.001083 0.006195
# merchanttype2 prodrating 0.001477 0.004720
# merchanttype2 reviewcount 0.000733 0.005729
# merchanttype2 negreview 0.001380 0.004705
# merchanttype2 posreview 0.001424 0.004767
# merchanttype2 answercnt 0.000889 0.004313
# merchanttype2 otheragreemean 0.001406 0.004706
# merchanttype2 ratingmosthelpful 0.001371 0.004705
# merchanttype2 possentiment 0.001374 0.004709
# merchanttype2 negsentiment 0.001475 0.004700
# merchanttype2 sentipolarity 0.001446 0.004712
# merchanttype2 reviewersrep 0.001388 0.004705
# merchanttype2 revpictotal 0.001245 0.004933
# merchanttype2 prodpicstotal 0.001430 0.004691
# merchanttype3 topads 0.001521 0.002697
# merchanttype3 cashback 0.001533 0.002708
# merchanttype3 cashbackval 0.001170 0.002659
# merchanttype3 price 0.002342 0.002610
# merchanttype3 prodrating 0.001574 0.002700
# merchanttype3 reviewcount 0.002576 0.002566
# merchanttype3 negreview 0.001540 0.002702
# merchanttype3 posreview 0.001568 0.002723
# merchanttype3 answercnt 0.001229 0.002762
# merchanttype3 otheragreemean 0.001491 0.002703
# merchanttype3 ratingmosthelpful 0.001543 0.002705
# merchanttype3 possentiment 0.001558 0.002717
# merchanttype3 negsentiment 0.001493 0.002688
# merchanttype3 sentipolarity 0.001488 0.002685
# merchanttype3 reviewersrep 0.001521 0.002702
# merchanttype3 revpictotal 0.001116 0.002807
# merchanttype3 prodpicstotal 0.001594 0.002701
# topads cashback 0.001355 0.004038
# topads cashbackval 0.001124 0.004013
# topads price 0.002121 0.003852
# topads prodrating 0.001465 0.004063
# topads reviewcount 0.000946 0.004171
# topads negreview 0.001350 0.004034
# topads posreview 0.001452 0.004041
# topads answercnt 0.001594 0.004149
# topads otheragreemean 0.001339 0.004045
# topads ratingmosthelpful 0.001397 0.004017
# topads possentiment 0.001437 0.004051
# topads negsentiment 0.001418 0.004036
# topads sentipolarity 0.001425 0.004059
# topads reviewersrep 0.001366 0.004038
# topads revpictotal 0.001000 0.004056
# topads prodpicstotal 0.001351 0.004027
# cashback cashbackval -0.000671 0.001647
# cashback price -0.000974 0.001667
# cashback prodrating -0.000560 0.001682
# cashback reviewcount -0.000902 0.001557
# cashback negreview -0.000624 0.001674
# cashback posreview -0.000609 0.001679
# cashback answercnt -0.000502 0.001652
# cashback otheragreemean -0.000585 0.001670
# cashback ratingmosthelpful -0.000615 0.001678
# cashback possentiment -0.000575 0.001672
# cashback negsentiment -0.000599 0.001683
# cashback sentipolarity -0.000575 0.001679
# cashback reviewersrep -0.000589 0.001674
# cashback revpictotal -0.000475 0.001677
# cashback prodpicstotal -0.000605 0.001691
# cashbackval price -0.017034 0.018204
# cashbackval prodrating -0.010716 0.017399
# cashbackval reviewcount -0.011733 0.018516
# cashbackval negreview -0.010577 0.017389
# cashbackval posreview -0.009998 0.017145
# cashbackval answercnt -0.009546 0.016589
# cashbackval otheragreemean -0.010429 0.017424
# cashbackval ratingmosthelpful -0.011133 0.017405
# cashbackval possentiment -0.010678 0.017628
# cashbackval negsentiment -0.010647 0.017517
# cashbackval sentipolarity -0.010597 0.017538
# cashbackval reviewersrep -0.010597 0.017417
# cashbackval revpictotal -0.008922 0.017542
# cashbackval prodpicstotal -0.011406 0.017420
# price prodrating -0.001779 0.082412
# price reviewcount 0.111902 0.105478
# price negreview -0.003758 0.081617
# price posreview -0.002079 0.082098
# price answercnt -0.004244 0.085066
# price otheragreemean -0.005001 0.082115
# price ratingmosthelpful -0.004894 0.082407
# price possentiment -0.003883 0.082440
# price negsentiment -0.004434 0.082527
# price sentipolarity -0.004317 0.082528
# price reviewersrep -0.004493 0.082232
# price revpictotal 0.005941 0.082892
# price prodpicstotal -0.003646 0.082930
# prodrating reviewcount 0.000187 0.005478
# prodrating negreview -0.000244 0.005385
# prodrating posreview -0.000226 0.005392
# prodrating answercnt -0.000147 0.005034
# prodrating otheragreemean -0.000416 0.005365
# prodrating ratingmosthelpful -0.000451 0.005389
# prodrating possentiment -0.000452 0.005387
# prodrating negsentiment -0.000451 0.005373
# prodrating sentipolarity -0.000288 0.005388
# prodrating reviewersrep -0.000402 0.005366
# prodrating revpictotal 0.000868 0.005500
# prodrating prodpicstotal -0.000439 0.005366
# reviewcount negreview 0.009720 0.085307
# reviewcount posreview 0.011239 0.083337
# reviewcount answercnt 0.009186 0.089052
# reviewcount otheragreemean 0.009800 0.084809
# reviewcount ratingmosthelpful 0.008453 0.084707
# reviewcount possentiment 0.009696 0.084363
# reviewcount negsentiment 0.009925 0.084254
# reviewcount sentipolarity 0.009552 0.084468
# reviewcount reviewersrep 0.009227 0.084465
# reviewcount revpictotal 0.023624 0.087277
# reviewcount prodpicstotal 0.010277 0.085081
# negreview posreview 0.000573 0.005250
# negreview answercnt 0.001215 0.005274
# negreview otheragreemean 0.000524 0.005246
# negreview ratingmosthelpful 0.000526 0.005259
# negreview possentiment 0.000538 0.005258
# negreview negsentiment 0.000390 0.005265
# negreview sentipolarity 0.000549 0.005280
# negreview reviewersrep 0.000510 0.005251
# negreview revpictotal 0.000529 0.005086
# negreview prodpicstotal 0.000550 0.005225
# posreview answercnt 0.004272 0.007863
# posreview otheragreemean 0.004962 0.007473
# posreview ratingmosthelpful 0.004941 0.007475
# posreview possentiment 0.004929 0.007466
# posreview negsentiment 0.005104 0.007464
# posreview sentipolarity 0.005092 0.007451
# posreview reviewersrep 0.005020 0.007451
# posreview revpictotal 0.005067 0.007590
# posreview prodpicstotal 0.004727 0.007386
# answercnt otheragreemean -0.001028 0.037104
# answercnt ratingmosthelpful -0.000794 0.037188
# answercnt possentiment -0.000292 0.037191
# answercnt negsentiment -0.000322 0.037104
# answercnt sentipolarity -0.000697 0.037164
# answercnt reviewersrep -0.000659 0.037125
# answercnt revpictotal 0.000728 0.038866
# answercnt prodpicstotal -0.000507 0.036781
# otheragreemean ratingmosthelpful 0.003193 0.002221
# otheragreemean possentiment 0.003251 0.002219
# otheragreemean negsentiment 0.003249 0.002212
# otheragreemean sentipolarity 0.003223 0.002224
# otheragreemean reviewersrep 0.003239 0.002217
# otheragreemean revpictotal 0.003243 0.002265
# otheragreemean prodpicstotal 0.003261 0.002237
# ratingmosthelpful possentiment 0.000153 0.004025
# ratingmosthelpful negsentiment 0.000174 0.004004
# ratingmosthelpful sentipolarity 0.000206 0.003986
# ratingmosthelpful reviewersrep 0.000182 0.004006
# ratingmosthelpful revpictotal 0.001074 0.003971
# ratingmosthelpful prodpicstotal 0.000133 0.004051
# possentiment negsentiment 0.000072 0.003446
# possentiment sentipolarity 0.000044 0.003480
# possentiment reviewersrep 0.000047 0.003442
# possentiment revpictotal 0.000115 0.003419
# possentiment prodpicstotal -0.000126 0.003481
# negsentiment sentipolarity 0.000066 0.005298
# negsentiment reviewersrep -0.000081 0.005302
# negsentiment revpictotal 0.000303 0.005334
# negsentiment prodpicstotal 0.000161 0.005338
# sentipolarity reviewersrep 0.000676 0.005830
# sentipolarity revpictotal 0.000704 0.005919
# sentipolarity prodpicstotal 0.000573 0.005822
# reviewersrep revpictotal 0.000000 0.000000
# reviewersrep prodpicstotal 0.000000 0.000000
# revpictotal prodpicstotal -0.003344 0.024733

# %%
Si['S1']
# Out:
# array([ 1.38919498e-03, -7.90457964e-04,  5.56141470e-04,  9.84435560e-04,
#         1.64748302e-02,  3.20142416e-01,  7.53735009e-04,  4.07346071e-01,
#        -2.74272872e-04, -1.56092987e-04,  8.77311580e-02, -9.28322186e-04,
#         9.43164291e-04,  3.68427573e-04,  3.15406915e-04,  7.64570896e-04,
#         0.00000000e+00,  2.14535459e-02, -3.57336667e-04])

# %%
??sobol.analyze
